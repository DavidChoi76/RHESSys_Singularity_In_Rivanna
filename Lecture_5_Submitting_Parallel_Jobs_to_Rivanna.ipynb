# %% [markdown]
# # Lecture_5_Submitting_Parallel_Jobs_to_Rivanna

# %% [markdown]
# * Before starting this notebook, you need to check your Jupyter Kernel as `Python 3.7`, because `!sbatch command` doesn't work in `rhessys` kernel

# %%
import os
current_dir = os.getcwd()

# %%
# Submit parallel job to Rivanna
# !sbatch {current_dir}/run.slurm
# Out:
# Submitted batch job 13055861

# %%
# Check the status of job submission. You have to change the number of Job submission from previous command
# !sacct -j 13055861 --format=jobID --format=jobname --format=Elapsed --format=state
# Out:
#        JobID    JobName    Elapsed      State
# ------------ ---------- ---------- ----------
# 13055861_0    run.slurm   01:10:03  COMPLETED
# 13055861_0.+      batch   01:10:03  COMPLETED
# 13055861_1    run.slurm   01:15:54  COMPLETED
# 13055861_1.+      batch   01:15:54  COMPLETED
# 13055861_2    run.slurm   01:10:53  COMPLETED
# 13055861_2.+      batch   01:10:53  COMPLETED
# 13055861_3    run.slurm   01:29:01  COMPLETED
# 13055861_3.+      batch   01:29:01  COMPLETED
# 13055861_4    run.slurm   01:08:32  COMPLETED
# 13055861_4.+      batch   01:08:32  COMPLETED
# 13055861_5    run.slurm   01:13:26  COMPLETED
# 13055861_5.+      batch   01:13:26  COMPLETED
# 13055861_6    run.slurm   01:17:29  COMPLETED
# 13055861_6.+      batch   01:17:29  COMPLETED
# 13055861_11   run.slurm   00:56:03  COMPLETED
# 13055861_11+      batch   00:56:03  COMPLETED
# 13055861_13   run.slurm   01:08:34  COMPLETED
# 13055861_13+      batch   01:08:34  COMPLETED
# ...
